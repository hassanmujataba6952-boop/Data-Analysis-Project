# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('adult.csv')

# %%
df.shape
# Out:
# (32561, 15)

# %%
pd.set_option('display.max_rows', None)
df
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      21790
# Female    10771
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df['age'].describe()
# Out:
# count    32561.000000
# mean        38.581647
# std         13.640433
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
sns.boxplot(data=df, x='age')
# Out:
# <Axes: xlabel='age'>

# %%
sns.countplot(data=df, y='education', hue='income')
# Out:
# <Axes: xlabel='count', ylabel='education'>

# %%
sns.kdeplot(data=df, x='age', hue='income', fill=True)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# # Project Summary
#
# Sir, is project mein main ne Income ka data analyze kiya hai:
# 1. Pehle data ko clean kiya aur check kiya ke is mein koi missing value nahi hai.
# 2. Phir graphs bana kar check kiya ke data mein mard aur auratein kitni hain.
# 3. Box Plot se pata chala ke zyada tar log 28 se 48 saal ki umar ke beech hain.
# 4. Aakhri graphs se nateeja nikla ke jin ki Parhai (Education) aur Umar (Tajurba) zyada hai, un ki Kamai (Income) bhi 50K se zyada hai.
